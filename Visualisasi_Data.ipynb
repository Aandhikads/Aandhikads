# %% [markdown]
# <a href="https://colab.research.google.com/github/Aandhikads/Aandhikads/blob/main/Visualisasi_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# %%
fig, ax = plt.subplots()

print(type(fig))
print(type(ax))
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig, ax = plt.subplots(figsize= (8, 6))
x = np.random.randint(1, 10, size = 10)
y= 2 * x
plt.plot(x, y)
plt.show()

# %%
fig, ax= plt.subplots(figsize = (8,6))
x = np.random.randint(1, 10,size =10)
y= 2 * x
plt.plot(x, y)
plt.plot(x, x+3)
plt.show()
