# %% [markdown]
# <a href="https://colab.research.google.com/github/Aandhikads/Aandhikads/blob/main/dilasi2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#contoh penggunaan diLae()
#dengan melibatkan argumen iteration

import cv2
import numpy as np

# %%
citra = cv2.imread('asu.jpg', 0)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
dilasi = cv2.dilate(citra, kernel, iterations = 3)
hasil = np.hstack((citra, dilasi))

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(hasil)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=2048x769 at 0x7F260390FE50>
# -1
